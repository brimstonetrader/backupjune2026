# %%
import numpy as np

xs = np.arange(300)
np.random.shuffle(xs)

with open('llmtest_shuffled.txt', 'r', encoding='utf-8') as f:
    lines1 = f.readlines()

p = []
for i in range(300):
    p.append(lines[xs[i]])

with open('llmtext_shuffled.txt', 'w', encoding='utf-8') as out:
    for line in p:
        out.write(line)

# %%
with open('llmtext_shuffled.txt', 'r', encoding='utf-8') as f:
    lines1 = f.readlines()

with open('labeled_2.txt', 'r', encoding='utf-8') as f:
    lines2 = f.readlines()

with open('labeled_3.txt', 'r', encoding='utf-8') as f:
    lines3 = f.readlines()

with open('labeled_4.txt', 'r', encoding='utf-8') as f:
    lines4 = f.readlines()

acc1 = 0
acc2 = 0
acc3 = 0

for i in range(299):
    if lines1[i] == lines2[i]:
        acc1 += 1
    if lines1[i][1] == lines3[i][1]:
        acc2 += 1
    if lines1[i] == lines4[i]:
        acc3 += 1
print('Accuracy of loud prompt: ', acc1 / 300)
print('Accuracy of sad prompt: ', acc2 / 300)
print('Accuracy of happy prompt: ', acc3 / 300)
# Out:
# Accuracy of loud prompt:  0.45666666666666667
# Accuracy of sad prompt:  0.11666666666666667
# Accuracy of happy prompt:  0.43333333333333335
